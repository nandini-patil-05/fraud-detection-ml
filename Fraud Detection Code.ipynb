# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv("fraud.csv")
df.head()
# Out:
#    transaction_id    amount      type  oldbalanceOrg  newbalanceOrig  \
# 0               1  18789.55     debit        5168.17        69816.17
# 1               2  47540.64     debit       53135.46        53609.64
# 2               3  36626.50  cash_out       54063.51        30952.76
# 3               4  29973.06   payment       63742.99        81379.50
# 4               5   7885.33     debit       72609.13        68473.12
#
#    oldbalanceDest  newbalanceDest  isFraud
# 0        53258.94        20788.63        0
# 1         5182.35         2653.22        1
# 2        33660.43        18143.54        0
# 3        13441.47        58304.16        1
# 4         6337.50        42142.46        1

# %%
# Check null values
print(df.isnull().sum())

# Convert categorical column
df = pd.get_dummies(df, columns=['type'], drop_first=True)
# Out:
# transaction_id    0
# amount            0
# type              0
# oldbalanceOrg     0
# newbalanceOrig    0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# dtype: int64

# %%
from imblearn.over_sampling import SMOTE

X = df.drop("isFraud", axis=1)
y = df["isFraud"]

smote = SMOTE()
X_res, y_res = smote.fit_resample(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=42)

# %%
model = RandomForestClassifier(n_estimators=100)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9324324324324325
# [[37  3]
#  [ 2 32]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94        40
#            1       0.91      0.94      0.93        34
#
#     accuracy                           0.93        74
#    macro avg       0.93      0.93      0.93        74
# weighted avg       0.93      0.93      0.93        74

# %%
importances = model.feature_importances_
features = X.columns

plt.figure(figsize=(10,6))
sns.barplot(x=importances, y=features)
plt.title("Feature Importance")
plt.show()
